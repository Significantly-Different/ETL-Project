# %%
#dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#importing dataset 1
csv_file = "data/fifa_20.csv"
players_20_df = pd.read_csv(csv_file)
players_20_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
#transforming dataset 1
new_players_20_df = players_20_df[['sofifa_id', 'short_name', 'overall', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']].copy()
new_players_20_df = new_players_20_df.dropna()
new_players_20_df.head()
# Out:
#    sofifa_id         short_name  overall  pace  shooting  passing  dribbling  \
# 0     158023           L. Messi       94  87.0      92.0     92.0       96.0
# 1      20801  Cristiano Ronaldo       93  90.0      93.0     82.0       89.0
# 2     190871          Neymar Jr       92  91.0      85.0     87.0       95.0
# 4     183277          E. Hazard       91  91.0      83.0     86.0       94.0
# 5     192985       K. De Bruyne       91  76.0      86.0     92.0       86.0
#
#    defending  physic
# 0       39.0    66.0
# 1       35.0    78.0
# 2       32.0    58.0
# 4       35.0    66.0
# 5       61.0    78.0

# %%
#loading into the database
rds_connection_string = "postgres:postgres@localhost:5432/fifa_20"
engine = create_engine(f'postgresql://{rds_connection_string}')
new_players_20_df.to_sql(name='fifa_20', con=engine, if_exists='append', index=False)

# %%
#confirmation queries
pd.read_sql_query('select * from fifa_20', con=engine).head()
# Out:
#    sofifa_id         short_name  overall  pace  shooting  passing  dribbling  \
# 0     158023           L. Messi       94  87.0      92.0     92.0       96.0
# 1      20801  Cristiano Ronaldo       93  90.0      93.0     82.0       89.0
# 2     190871          Neymar Jr       92  91.0      85.0     87.0       95.0
# 3     183277          E. Hazard       91  91.0      83.0     86.0       94.0
# 4     192985       K. De Bruyne       91  76.0      86.0     92.0       86.0
#
#    defending  physic
# 0       39.0    66.0
# 1       35.0    78.0
# 2       32.0    58.0
# 3       35.0    66.0
# 4       61.0    78.0
